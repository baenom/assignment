# %%
import random

def f(x):
    return (x-3)**2 +4

def dx_f(x):
    return 2*(x-3)

L = 0.001

iterations =10

x = random.randint(-15,15)

# %%
x =

# %%
for i in range(iterations):
    d_x = dx_f(x)
    x -= L*d_x
    print(x,f(x))
# Out:
# -10.695061593713437 191.55471205560482
# -10.66767147052601 190.80524342623062
# -10.640336127584957 190.0587696734994
# -10.613055455329787 189.31527882988408
# -10.585829344419128 188.57475897567988
# -10.55865768573029 187.83719823881307
# -10.53154037035883 187.10258479465077
# -10.504477289618112 186.37090686581135
# -10.477468335038877 185.64215272197558
# -10.450513398368798 184.91631067969857
