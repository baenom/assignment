# %%
from sympy import *
import numpy as np
a = 1
b = 3
x = symbols('x')#arange(0,0.1,10)
logistic = 1/(1+exp(-(a*x+b)))
plot(logistic)
# Out:
#       1 |                             ..........................
#         |                          ...
#         |                         /
#         |                        /
#         |                       /
#         |                      /
#         |                     .
#         |
#         |                    .
#         |
#     0.5 |-------------------.-----------------------------------
#         |
#         |                  .
#         |                 .
#         |
#         |                .
#         |               /
#         |              /
#         |             /
#         |          ...
#       0 |_______________________________________________________
#          -10                        0                          10
